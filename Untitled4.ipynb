# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-48a28829-d44d-4d94-bab3-69d8165a7313" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48a28829-d44d-4d94-bab3-69d8165a7313">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import seaborn as sns
import numpy as np


print("✅ Dataset 'Iris' cargado exitosamente.\n")


print("--- 2.1 head(): Primeras 5 filas (Vista rápida de datos) ---")
display(df.head())

print("\n--- 2.2 tail(): Últimas 5 filas (Ver colas o pies de página) ---")
display(df.tail())

print("\n--- 2.3 shape: Dimensiones del dataset (Filas, Columnas) ---")
print(df.shape)

print("\n--- 2.4 info(): Tipos de datos, nulos y uso de memoria ---")
df.info()

print("\n--- 2.5 describe(): Estadísticas descriptivas de columnas numéricas ---")
display(df.describe())


print("\n--- 3. CÁLCULO DE ESTADÍSTICAS ---")

# 1. Moda (Valor más frecuente) de la longitud del sépalo
moda_longitud = df['sepal_length'].mode()[0]
print(f"1. Moda de la longitud del sépalo (cm): {moda_longitud:.2f} cm (La medida más común)")

# 2. Varianza de la amplitud del pétalo (dispersión de los datos)
varianza_amplitud = df['petal_width'].var()
print(f"2. Varianza de la amplitud del pétalo: {varianza_amplitud:.3f} (Muestra qué tan dispersos están los valores)")

# 3. Conteo de valores únicos en la columna de especies (la variable objetivo)
conteo_especies = df['species'].value_counts()
print("\n3. Conteo de especies (Cuántas flores hay de cada tipo):")
print(conteo_especies)


df['sepal_ratio'] = df['sepal_length'] / df['sepal_width']

print("\n--- 4. NUEVA COLUMNA CREADA: 'sepal_ratio' ---")
display(df[['sepal_length', 'sepal_width', 'sepal_ratio']].head())
print(f"Se ha añadido una nueva columna, las dimensiones ahora son: {df.shape}")

# %% [markdown]
# **Hallazgos Clave del Dataset Iris**
# **Estructura del Dataset (.shape y .info()):**
#
# El dataset contiene 150 filas (observaciones) y 5 columnas (características).
#
# No se detectaron valores nulos (Non-Null Count es 150 en todas las columnas), lo que indica un dataset muy limpio.
#
# Todas las columnas de medidas (sepal_length, etc.) son de tipo float64 (decimales), ideales para cálculos estadísticos.
#
# **Estadísticas Descriptivas (.describe()):**
#
# La media de la longitud del sépalo (sepal_length) es de aproximadamente 5.84 cm.
#
# La flor con la mayor longitud de pétalo (petal_length) mide 6.9 cm, y la menor mide 1.0 cm, lo que indica una gran variabilidad entre las especies.
#
# La desviación estándar es baja en la mayoría de las columnas, indicando que los valores no están extremadamente dispersos respecto a la media.
#
# **Insights Generados:**
#
# El dataset está perfectamente balanceado: hay 50 ejemplares de cada una de las tres especies (setosa, versicolor, virginica).
#
# El nuevo cálculo de sepal_ratio permite crear un factor de forma que puede ser útil para la clasificación de las especies.
